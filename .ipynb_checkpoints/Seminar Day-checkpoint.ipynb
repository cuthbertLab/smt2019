# %% [markdown]
# # Seminar Schedule
#
# ## 1. Introductions (9:05-9:15)

# %% [markdown]
# ## 2. Techy setup (9:15-9:30)
#
# We'll work with each other to make sure that we all have a system for solving a particular problem:

# %%
beach = corpus.parse('beach')

# %%
beach.show()

# %% [markdown]
# ## 3. Working with Beach Score (9:30-10:15)

# %%
voiceParts = beach.parts[0:4]
for vp in voiceParts:
    print(vp.id)
# Out:
# Soprano I
# Soprano II
# Alto I
# Alto II

# %%
from collections import Counter
numRepeatedNotes = Counter()

# %%
for partNumber in range(4):
    vp = voiceParts[partNumber]
    lastPS = 9999
    for n in vp.recurse().notes:
        thisPS = n.pitch.ps
        if thisPS == lastPS:
            numRepeatedNotes[partNumber] += 1
        lastPS = thisPS

# %%
numRepeatedNotes
# Out:
# Counter({0: 39, 1: 8, 2: 12, 3: 78})

# %%
for bachPiece in corpus.chorales.Iterator():
    if len(bachPiece.parts) != 4:
        continue
    numRepeatedNotes = Counter()
    for partNumber in range(4):
        vp = bachPiece.parts[partNumber]
        lastPS = 9999
        for n in vp.recurse().notes:
            thisPS = n.pitch.ps
            if thisPS == lastPS:
                numRepeatedNotes[partNumber] += 1
            lastPS = thisPS
    partNumberWithMostRepetitions = numRepeatedNotes.most_common(1)[0][0]
    print(partNumberWithMostRepetitions, bachPiece.metadata.title)
# Out:
# 2 Aus meines Herzens Grunde
# 2 Ich dank’ dir, lieber Herre
# 1 Ach Gott, vom Himmel sieh’ darein
# 2 Es ist das Heil uns kommen her
# 2 An Wasserflüssen Babylon
# 1 Christus, der ist mein Leben
# 0 Nun lob’, mein’ Seel’, den Herren
# 0 Freuet euch, ihr Christen alle
# 2 Ermuntre dich, mein schwacher Geist
# 1 Aus tiefer Not schrei’ ich zu dir
# 1 Puer natus in Bethlehem
# 1 Allein zu dir, Herr Jesu Christ
# 1 O Herre Gott, dein göttlich Wort
# 1 Christ lag in Todesbanden
# 2 Es woll’ uns Gott genädig sein
# 1 Erschienen ist der herrliche Tag
# 1 Gottes Sohn ist kommen
# 2 Ich hab’ mein’ Sach’ Gott heimgestellt
# 2 Ein’ feste Burg ist unser Gott
# 2 Herzlich tut mich verlangen
# 1 Schmücke dich, o liebe Seele
# 1 Zeuch ein zu deinen Toren
# 1 Valet will ich dir geben
# 1 Wo soll ich fliehen hin
# 1 O Ewigkeit, du Donnerwort
# 1 Es spricht der Unweisen Mund
# 0 Nun komm, der Heiden Heiland
# 1 Freu’ dich sehr, o meine Seele
# 0 Jesus Christus, unser Heiland
# 2 Ach lieben Christen, seid getrost
# 1 Nun danket alle Gott
# 1 Herr, ich habe mißgehandelt
# 1 Erbarm’ dich mein, o Herre Gott
# 1 Gott des Himmels und der Erden
# 1 Nun bitten wir den heiligen Geist
# 1 Jesu, der du meine Seele
# 1 Straf’ mich nicht in deinem Zorn
# 2 Ach bleib bei uns, Herr Jesu Christ
# 2 Das neugeborne Kindelein
# 2 Wachet auf, ruft uns die Stimme
# 1 Als Jesus Christus in der Nacht
# 2 Gott hat das Evangelium
# 1 Wär’ Gott nicht mit uns diese Zeit
# 1 Nun freut euch, lieben Christen, g’mein
# 1 Christ lag in Todesbanden
# 1 Nun freut euch, Gottes Kinder all’
# 1 Ach Gott, erhör’ mein Seufzen
# 1 Komm, Gott Schöpfer, heiliger Geist
# 2 Ich dank’ dir schon durch deinen Sohn
# 2 Herr Jesu Christ, wahr’r Mensch und Gott
# 2 Herr, nun laß in Friede
# 1 Von Gott will ich nicht lassen
# 0 Gottlob, es geht nunmehr zu Ende
# 2 Was bist du doch, o Seele, so betrübet
# 2 Liebster Immanuel, Herzog der Frommen
# 1 Wie schön leuchtet der Morgenstern
# 1 Da der Herr Christ zu Tische saß
# 1 Christ ist erstanden
# 2 Christus, der uns selig macht
# 1 Hilf, Gott, daß mir’s gelinge
# 2 Christus ist erstanden, hat überwunden
# 1 O Mensch, bewein’ dein’ Sünde groß
# 0 O wir armen Sünder
# 1 O Mensch, schau’ Jesum Christum an
# 1 Wer weiß, wie nahe mir mein Ende
# 0 Herr Gott, dich loben wir
# 1 So gibst du nun, mein Jesu, gute Nacht
# 2 Des Heil’gen Geistes reiche Gnad’
# 2 Als vierzig Tag’ nach Ostern war
# 1 Dir, dir, Jehova, will ich singen
# 1 Christe, du Beistand deiner Kreuzgemeine
# 2 Weltlich’ Ehr’ und zeitlich Gut
# 1 Herr, ich denk’ an jene Zeit
# 2 O wie selig seid ihr doch, ihr Frommen
# 1 Mitten wir im Leben sind
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-097cd234e521> in <module>
# ----> 1 for bachPiece in corpus.chorales.Iterator():
#       2     if len(bachPiece.parts) != 4:
#       3         continue
#       4     numRepeatedNotes = Counter()
#       5     for partNumber in range(4):
#
# ~/git/music21base/music21/corpus/chorales.py in __next__(self)
#    1165         if self._currentIndex > self._highestIndex:
#    1166             raise StopIteration
# -> 1167         nextChorale = self._returnChorale()
#    1168         self._currentIndex += 1
#    1169         return nextChorale
#
# ~/git/music21base/music21/corpus/chorales.py in _returnChorale(self, choraleIndex)
#    1264
#    1265         if self._returnType == 'stream':
# -> 1266             chorale = corpus.parse(filename)
#    1267             if self.numberingSystem == 'riemenschneider' and self.analysis:
#    1268                 # noinspection PyBroadException
#
# ~/git/music21base/music21/corpus/__init__.py in parse(workName, movementNumber, number, fileExtensions, forceSource, format)
#     327         fileExtensions=fileExtensions,
#     328         forceSource=forceSource,
# --> 329         format=format  # @ReservedAssignment
#     330     )
#     331
#
# ~/git/music21base/music21/corpus/manager.py in parse(workName, movementNumber, number, fileExtensions, forceSource, format)
#     183         forceSource=forceSource,
#     184         number=number,
# --> 185         format=format
#     186     )
#     187     _addCorpusFilepathToStreamObject(streamObject, filePath)
#
# ~/git/music21base/music21/converter/__init__.py in parse(value, *args, **keywords)
#    1123     elif not isinstance(value, bytes) and os.path.exists(valueStr):
#    1124         return parseFile(valueStr, number=number, format=m21Format,
# -> 1125                          forceSource=forceSource, **keywords)
#    1126     elif not isinstance(value, bytes) and os.path.exists(common.cleanpath(valueStr)):
#    1127         return parseFile(common.cleanpath(valueStr), number=number, format=m21Format,
#
# ~/git/music21base/music21/converter/__init__.py in parseFile(fp, number, format, forceSource, **keywords)
#     998     v = Converter()
#     999     fp = common.cleanpath(fp, returnPathlib=True)
# -> 1000     v.parseFile(fp, number=number, format=format, forceSource=forceSource, **keywords)
#    1001     return v.stream
#    1002
#
# ~/git/music21base/music21/converter/__init__.py in parseFile(self, fp, number, format, forceSource, storePickle, **keywords)
#     541         else:
#     542             environLocal.printDebug('Loading original version')
# --> 543             self.parseFileNoPickle(fp, number, format, forceSource, **keywords)
#     544             if writePickle is True and fpPickle is not None and storePickle is True:
#     545                 # save the stream to disk...
#
# ~/git/music21base/music21/converter/__init__.py in parseFileNoPickle(self, fp, number, format, forceSource, **keywords)
#     475         self.subConverter.keywords = keywords
#     476         try:
# --> 477             self.subConverter.parseFile(fp, number=number, **keywords)
#     478         except NotImplementedError:
#     479             raise ConverterFileException('File is not in a correct format: %s' % fp)
#
# ~/git/music21base/music21/converter/subConverters.py in parseFile(self, fp, number)
#     863             archData = arch.getData()
#     864             c.xmlText = archData
# --> 865             c.parseXMLText()
#     866         else:  # its a file path or a raw musicxml string
#     867             c.readFile(fp)
#
# ~/git/music21base/music21/musicxml/xmlToM21.py in parseXMLText(self)
#     856             raise MusicXMLImportException('Cannot parse MusicXML files not in score-partwise. '
#     857                                           + "Root tag was '{0}'".format(self.xmlRoot.tag))
# --> 858         self.xmlRootToScore(self.xmlRoot, self.stream)
#     859
#     860     def xmlRootToScore(self, mxScore, inputM21=None):
#
# ~/git/music21base/music21/musicxml/xmlToM21.py in xmlRootToScore(self, mxScore, inputM21)
#     896                 continue
#     897
# --> 898             part = self.xmlPartToPart(p, mxScorePart)
#     899
#     900             if part is not None:  # for instance, in partStreams
#
# ~/git/music21base/music21/musicxml/xmlToM21.py in xmlPartToPart(self, mxPart, mxScorePart)
#     930         '''
#     931         parser = PartParser(mxPart, mxScorePart=mxScorePart, parent=self)
# --> 932         parser.parse()
#     933         if parser.appendToScoreAfterParse is True:
#     934             return parser.stream
#
# ~/git/music21base/music21/musicxml/xmlToM21.py in parse(self)
#    1470         '''
#    1471         self.parseXmlScorePart()
# -> 1472         self.parseMeasures()
#    1473         self.stream.atSoundingPitch = self.atSoundingPitch
#    1474
#
# ~/git/music21base/music21/musicxml/xmlToM21.py in parseMeasures(self)
#    1611         part = self.stream
#    1612         for mxMeasure in self.mxPart.iterfind('measure'):
# -> 1613             self.xmlMeasureToMeasure(mxMeasure)
#    1614
#    1615         # self.removeEndForwardRest()
#
# ~/git/music21base/music21/musicxml/xmlToM21.py in xmlMeasureToMeasure(self, mxMeasure)
#    1777         measureParser = MeasureParser(mxMeasure, parent=self)
#    1778         try:
# -> 1779             measureParser.parse()
#    1780         except Exception as e:  # pylint: disable=broad-except
#    1781             self.measureParsingError(mxMeasure, e)
#
# ~/git/music21base/music21/musicxml/xmlToM21.py in parse(self)
#    2319                 if methName is not None:
#    2320                     meth = getattr(self, methName)
# -> 2321                     meth(mxObj)
#    2322
#    2323         if self.useVoices is True:
#
# ~/git/music21base/music21/musicxml/xmlToM21.py in xmlToNote(self, mxNote)
#    2470             self.restAndNoteCount['note'] += 1
#    2471             try:
# -> 2472                 n = self.xmlToSimpleNote(mxNote)
#    2473             except MusicXMLImportException as strerror:
#    2474                 raise MusicXMLImportException(
#
# ~/git/music21base/music21/musicxml/xmlToM21.py in xmlToSimpleNote(self, mxNote, freeSpanners)
#    2631         # TODO: beams over rests?
#    2632         '''
# -> 2633         n = note.Note()
#    2634
#    2635         # send whole note since accidental display not in <pitch>
#
# ~/git/music21base/music21/note.py in __init__(self, pitchName, **keywords)
#    1060     # Accepts an argument for pitch
#    1061     def __init__(self, pitchName=None, **keywords):
# -> 1062         super().__init__(**keywords)
#    1063
#    1064         if 'pitch' in keywords and pitchName is None:
#
# ~/git/music21base/music21/note.py in __init__(self, *arguments, **keywords)
#     707
#     708     def __init__(self, *arguments, **keywords):
# --> 709         super().__init__(**keywords)
#     710         self._notehead = 'normal'
#     711         self._noteheadFill = None
#
# ~/git/music21base/music21/note.py in __init__(self, *arguments, **keywords)
#     372             tempDuration = keywords['duration']
#     373         # this sets the stored duration defined in Music21Object
# --> 374         super().__init__(duration=tempDuration)
#     375
#     376         self.lyrics = []  # a list of lyric objects
#
# ~/git/music21base/music21/base.py in __init__(self, *arguments, **keywords)
#     388             self.sites = keywords['sites']
#     389         else:
# --> 390             self.sites = sites.Sites()
#     391
#     392         # a duration object is not created until the .duration property is
#
# ~/git/music21base/music21/sites.py in __init__(self)
#     188     def __init__(self):
#     189         # .siteDict is a dictionary of siteRefs.  None is a singleton.
# --> 190         self.siteDict = collections.OrderedDict([(None, _NoneSiteRef), ])
#     191
#     192         # store an index of numbers for tagging the order of creation of defined contexts;
#
# KeyboardInterrupt:

# %%
for bachPiece in corpus.chorales.Iterator():
    if len(bachPiece.parts) != 4:
        continue
    numRepeatedNotes = Counter()
    for partNumber in range(4):
        vp = bachPiece.parts[partNumber]
        lastPS = 9999
        for n in vp.recurse().notes:
            thisPS = n.pitch.ps
            if thisPS == lastPS:
                numRepeatedNotes[partNumber] += 1
            lastPS = thisPS
    partNumberWithMostRepetitions = numRepeatedNotes.most_common(1)[0][0]
    if partNumberWithMostRepetitions == 3:
        print(partNumberWithMostRepetitions, bachPiece.metadata.title)

# %% [markdown]
# ## 4. What other questions do we have?  What would we need to do more with this piece? (10:15-10:35)
#
# What sorts of questions are conducive to corpus studies?  What are not?

# %% [markdown]
# ## 5. Break 10:35-10:45

# %% [markdown]
# ## 6. Individual Corpora (10:45-11:00)
#
# Working through the questions from seminar 1 and esp. 2
#
#
# ## 7. More hacking (11:00–12:00)
